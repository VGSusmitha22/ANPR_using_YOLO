# %%
# ============================================
# ANPR Project Setup (Automatic Number Plate Recognition)
# ============================================

# Step 1: Clone Ultralytics YOLOv8 repository
# !git clone https://github.com/ultralytics/ultralytics.git

# Step 2: Install required libraries for ANPR
# !pip install easyocr         # For text recognition (OCR)
# !pip install pytesseract     # Alternative OCR engine
# !pip install roboflow        # Dataset management

# Step 3: Install YOLOv8 and dependencies
# !pip install ultralytics==8.0.3
# !pip install hydra-core>=1.2.0
# !pip install matplotlib>=3.2.2
# !pip install numpy>=1.18.5
# !pip install opencv-python>=4.1.1
# !pip install Pillow>=7.1.2
# !pip install PyYAML>=5.3.1
# !pip install requests>=2.23.0
# !pip install scipy>=1.4.1
# !pip install torch>=1.7.0
# !pip install torchvision>=0.8.1
# !pip install tqdm>=4.64.0

# Logging & Visualization
# !pip install tensorboard>=2.4.1
# !pip install pandas>=1.1.4
# !pip install seaborn>=0.11.0

# Utilities
# !pip install ipython
# !pip install psutil
# !pip install thop>=0.1.1
# !pip install GitPython>=3.1.24

# ============================================
# Step 4: Download ANPR Dataset from Roboflow
# ============================================

from roboflow import Roboflow

rf = Roboflow(api_key="YOUR_API_KEY")  # Replace with your API key
project = rf.workspace("mochoye").project("license-plate-detector-ogxxg")

version = project.version(2)
dataset = version.download("yolov8")

print("Dataset downloaded successfully for ANPR ")
